# %%
# import libraries
from IPython.display import display  # The display function is used to display various types of content in the output area of a Jupyter notebook 
# or IPython terminal. Once imported, you can use the display function to show things like images, audio, video, HTML, and Markdown text. 
import numpy as np
import pandas as pd

# %%
# pandas version I am using
pd.__version__
# Out:
# '1.1.5'

# %%
#  If a DataFrame or Series has more than 20 rows, only the first 10 and last 10 rows will be displayed, with the middle rows truncated.
pd.options.display.min_rows = 20

# %%
autos = pd.read_csv('https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip')
# Out:
# c:\Users\Dave\anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3258: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# autos = pd.read_csv('C:/Users/Dave/Desktop/Basic Python/vehicles.csv')

# %%
autos
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# 5      14.982273         0.0        0.0        0.0      21      0.0        0
# 6      13.184400         0.0        0.0        0.0      22      0.0        0
# 7      13.733750         0.0        0.0        0.0      23      0.0        0
# 8      12.677308         0.0        0.0        0.0      23      0.0        0
# 9      13.184400         0.0        0.0        0.0      23      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# ...

# %%
# columns in the data frame
autos.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %% [markdown]
# ## Types

# %%
# choose a couple of columns from the data frame
cols = ['city08','comb08','highway08','cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year']

# %%
# what data types  do we have here 
autos[cols].dtypes
# Out:
# city08          int64
# comb08          int64
# highway08       int64
# cylinders     float64
# displ         float64
# drive          object
# eng_dscr       object
# fuelCost08      int64
# make           object
# model          object
# trany          object
# range           int64
# createdOn      object
# year            int64
# dtype: object

# %%
autos[cols].memory_usage(deep=True)
# Out:
# Index             128
# city08         329152
# comb08         329152
# highway08      329152
# cylinders      329152
# displ          329152
# drive         3028369
# eng_dscr      2135693
# fuelCost08     329152
# make          2606267
# model         2813134
# trany         2933276
# range          329152
# createdOn     3497240
# year           329152
# dtype: int64

# %%
autos[cols].memory_usage(deep=True).sum() # roughly 19megs of memory
# Out:
# 19647323

# %%
autos[cols].describe()
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  41144.000000  41144.000000  41144.000000  40938.000000  40940.000000
# mean      18.369045     20.616396     24.504667      5.717084      3.294238
# std        7.905886      7.674535      7.730364      1.755517      1.357151
# min        6.000000      7.000000      9.000000      2.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       20.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    136.000000    124.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000
# mean    2362.335942      0.793506   2001.535266
# std      654.981925     13.041592     11.142414
# min      500.000000      0.000000   1984.000000
# ...

# %% [markdown]
# ## Int

# %%
(autos
 [cols]
 .select_dtypes(int)
 .describe()
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9696\2187649983.py in <module>
#       1 (autos
#       2  [cols]
# ----> 3  .select_dtypes(int)
#       4  .describe()
#       5 )
#
# c:\Users\Dave\anaconda3\envs\myenv\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9978         """
#    9979         if self.ndim == 2 and self.columns.size == 0:
# -> 9980             raise ValueError("Cannot describe a DataFrame without columns")
#    9981
#    9982         if percentiles is not None:
#
# ValueError: Cannot describe a DataFrame without columns

# %%
# can comb08 be int8?
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
# change types
(autos
 [cols]
 .astype({'highway08':'int8', 'city08':'int16','comb08':'int16'})
 .select_dtypes([int, 'int8'])
 .describe()
)
# Out:
#           highway08
# count  41144.000000
# mean      24.504667
# std        7.730364
# min        9.000000
# 25%       20.000000
# 50%       24.000000
# 75%       28.000000
# max      124.000000

# %%
# chaining 
# use integer to see all int-like columns
(autos
 [cols]
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16','fuelCost08':'int16', 'range':'int16', 'year':'int16'})
 .select_dtypes(['integer'])
 .describe()
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %%
(autos
 [cols]
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16','fuelCost08':'int16', 'range':'int16', 'year':'int16'})
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 18124995

# %% [markdown]
# ## Floats

# %%
(autos
 [cols]
 .select_dtypes('float'))
# Out:
#        cylinders  displ
# 0            4.0    2.0
# 1           12.0    4.9
# 2            4.0    2.2
# 3            8.0    5.2
# 4            4.0    2.2
# 5            4.0    1.8
# 6            4.0    1.8
# 7            4.0    1.6
# 8            4.0    1.6
# 9            4.0    1.8
# ...          ...    ...
# 41134        4.0    2.1
# 41135        4.0    1.9
# 41136        4.0    1.9
# 41137        4.0    1.9
# 41138        4.0    1.9
# 41139        4.0    2.2
# 41140        4.0    2.2
# 41141        4.0    2.2
# 41142        4.0    2.2
# 41143        4.0    2.2
#
# [41144 rows x 2 columns]

# %%
# surprise! cylinders look float like
autos.cylinders.describe()
# Out:
# count    40938.000000
# mean         5.717084
# std          1.755517
# min          2.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: cylinders, dtype: float64

# %% [markdown]
# count means # of values that were not missing. Initially we had 41144 rows but count of cylinders is 40938. Meaning we have missing values. Hence floats instead of ints

# %%
# oops! missing values
autos.cylinders.value_counts(dropna=False)
# Out:
# 4.0     15938
# 6.0     14284
# 8.0      8801
# 5.0       771
# 12.0      626
# 3.0       279
# NaN       206
# 10.0      170
# 2.0        59
# 16.0       10
# Name: cylinders, dtype: int64

# %%
# where are they missing
autos.loc[autos['cylinders'].isna(),:]
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08   city08U  cityA08  \
# 7138     0.24000         0.0        0.0        0.0      81    0.0000        0
# 7139     0.28200         0.0        0.0        0.0      81    0.0000        0
# 8143     0.28200         0.0        0.0        0.0      81    0.0000        0
# 8144     0.31200         0.0        0.0        0.0      74    0.0000        0
# 8146     0.52200         0.0        0.0        0.0      45    0.0000        0
# 8147     0.27000         0.0        0.0        0.0      84    0.0000        0
# 9212     0.25800         0.0        0.0        0.0      87    0.0000        0
# 9213     0.52200         0.0        0.0        0.0      45    0.0000        0
# 10329    0.25800         0.0        0.0        0.0      87    0.0000        0
# 21413   13.73375         0.0        0.0        0.0      22    0.0000        0
# ...          ...         ...        ...        ...     ...       ...      ...
# ...

# %%
# chaining ass cylinders and displ columns
(autos
[cols]
.assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
        displ = autos.displ.fillna(0))
.astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16','fuelCost08':'int16','range':'int16', 'year':'int16',})
.describe()
)
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667      5.688460      3.277904
# std        7.905886      7.674535      7.730364      1.797009      1.373415
# min        6.000000      7.000000      9.000000      0.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       20.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    136.000000    124.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000
# mean    2362.335942      0.793506   2001.535266
# std      654.981925     13.041592     11.142414
# min      500.000000      0.000000   1984.000000
# ...

# %%
autos[cols].describe()
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  41144.000000  41144.000000  41144.000000  40938.000000  40940.000000
# mean      18.369045     20.616396     24.504667      5.717084      3.294238
# std        7.905886      7.674535      7.730364      1.755517      1.357151
# min        6.000000      7.000000      9.000000      2.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       20.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    136.000000    124.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000
# mean    2362.335942      0.793506   2001.535266
# std      654.981925     13.041592     11.142414
# min      500.000000      0.000000   1984.000000
# ...

# %%
# inspect float sizes
np.finfo(np.float16)
# Out:
# finfo(resolution=0.001, min=-6.55040e+04, max=6.55040e+04, dtype=float16)

# %%
# chaining - convert displ to float16
(autos
 [cols]
 .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
        displ = autos.displ.fillna(0).astype('float16'))
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16','fuelCost08':'int16','range':'int16', 'year':'int16',})
)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# ...

# %%
# new memory usage
(autos
 # cols
 .loc[:, cols]
  .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
        displ = autos.displ.fillna(0).astype('float16'))
.astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16','fuelCost08':'int16','range':'int16', 'year':'int16',})
.memory_usage(deep=True)
.sum()
) # was 19,647, 323
# Out:
# 17590123

# %% [markdown]
# ## Objects

# %%
(autos
 [cols]
 .select_dtypes(object)
)
# Out:
#                             drive          eng_dscr        make  \
# 0                Rear-Wheel Drive             (FFS)  Alfa Romeo
# 1                Rear-Wheel Drive         (GUZZLER)     Ferrari
# 2               Front-Wheel Drive             (FFS)       Dodge
# 3                Rear-Wheel Drive               NaN       Dodge
# 4      4-Wheel or All-Wheel Drive        (FFS,TRBO)      Subaru
# 5               Front-Wheel Drive             (FFS)      Subaru
# 6               Front-Wheel Drive             (FFS)      Subaru
# 7               Front-Wheel Drive             (FFS)      Toyota
# 8               Front-Wheel Drive             (FFS)      Toyota
# 9               Front-Wheel Drive             (FFS)      Toyota
# ...                           ...               ...         ...
# 41134           Front-Wheel Drive             (FFS)        Saab
# 41135           Front-Wheel Drive  (TBI)      (FFS)      Saturn
# 41136           Front-Wheel Drive  (MFI)      (FFS)      Saturn
# ...

# %% [markdown]
# Drive is pseudo categorical.
# eng_descr looks categorical / free form.
# make looks categorical.
# model pseudo categorical.A high cardinality.
# Transmission looks categorical.
# created on - date.

# %%
# drive looks categorical
(autos.drive.value_counts(dropna=False))
# Out:
# Front-Wheel Drive             14236
# Rear-Wheel Drive              13831
# 4-Wheel or All-Wheel Drive     6648
# All-Wheel Drive                3015
# 4-Wheel Drive                  1460
# NaN                            1189
# 2-Wheel Drive                   507
# Part-time 4-Wheel Drive         258
# Name: drive, dtype: int64

# %%
# what cars don't have a drive?
autos.loc[autos.drive.isna(), cols]
# Out:
#        city08  comb08  highway08  cylinders  displ drive            eng_dscr  \
# 7138       81      85         91        NaN    NaN   NaN                 NaN
# 8144       74      65         58        NaN    NaN   NaN                 NaN
# 8147       84      75         66        NaN    NaN   NaN                 NaN
# 18217      18      21         25        4.0    2.0   NaN               (FFS)
# 18218      20      22         26        4.0    1.5   NaN               (FFS)
# 18219      13      15         20        8.0    5.7   NaN      (350 V8) (FFS)
# 18220      13      15         20        8.0    5.7   NaN      (350 V8) (FFS)
# 18221      15      17         20        6.0    3.0   NaN          (FFS,TRBO)
# 18222      16      18         20        6.0    3.0   NaN               (FFS)
# 18223      16      18         22        6.0    3.0   NaN          (FFS,TRBO)
# ...       ...     ...        ...        ...    ...   ...                 ...
# ...

# %%
(autos
 [cols]
 .groupby('year')
 .drive
 .nunique())
# Out:
# year
# 1984    3
# 1985    4
# 1986    4
# 1987    3
# 1988    3
# 1989    3
# 1990    3
# 1991    3
# 1992    3
# 1993    3
# 1994    3
# 1995    4
# 1996    3
# 1997    4
# 1998    4
# 1999    4
# 2000    4
# 2001    4
# 2002    4
# 2003    4
# 2004    4
# 2005    4
# 2006    4
# 2007    4
# 2008    3
# 2009    4
# 2010    6
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# Name: drive, dtype: int64

# %%
# drive and make ( in . astype) to category
(autos
 [cols]
 .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
         displ = autos.displ.fillna(0).astype('float16'),
         drive = autos.drive.fillna('Other').astype('category')
         )
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
 .memory_usage(deep=True) # was 19,647323
 .sum()
)
# Out:
# 12094247

# %%
# lets inspect trany
# looks like it has two pieces of information embedded in one column
(autos
 .trany
 .value_counts(dropna=False)
)
# Out:
# Automatic 4-spd                     11047
# Manual 5-spd                         8361
# Automatic 3-spd                      3151
# Automatic (S6)                       3106
# Manual 6-spd                         2757
# Automatic 5-spd                      2203
# Automatic (S8)                       1665
# Automatic 6-spd                      1619
# Manual 4-spd                         1483
# Automatic (S5)                        833
# Automatic (variable gear ratios)      826
# Automatic 7-spd                       724
# Automatic 8-spd                       433
# Automatic (AM-S7)                     424
# Automatic (S7)                        327
# Automatic 9-spd                       293
# Automatic (AM7)                       245
# Automatic (S4)                        233
# Automatic (AV-S6)                     208
# Automatic (A1)                        201
# Automatic (AM6)                       151
# Automatic (AV-S7)                     139
# ...

# %%
# add automatic, speeds from trany, then drop trany
(autos
 [cols]
 .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
         displ = autos.displ.fillna(0).astype('float16'),
         drive = autos.drive.fillna('Other').astype('category'),
         automatic = autos.trany.str.contains('Auto'), # indicator true/false
         speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8') # extract the digits
         )
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
 .drop(columns = ['trany'])
 .memory_usage(deep=True) # was 19,647323
 .sum()
)
# Out:
# 10632019

# %% [markdown]
# ## Dates

# %%
# add Created on
(autos
 [cols]
 .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
         displ = autos.displ.fillna(0).astype('float16'),
         drive = autos.drive.fillna('Other').astype('category'),
         automatic = autos.trany.str.contains('Auto'), # indicator true/false
         speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'), # extract the digits
         createdOn = pd.to_datetime(autos.createdOn).dt.tz_localize('America/New_York')
         )
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
 .drop(columns = ['trany'])
 .memory_usage(deep=True) # was 19,647323
 .sum()
)
# Out:
# c:\Users\Dave\anaconda3\envs\myenv\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c:\Users\Dave\anaconda3\envs\myenv\lib\site-packages\dateutil\parser\_parser.py:1212: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# 7463931

# %%
# python doesn't like EST/EDT
autos[cols].createdOn
# Out:
# 0        Tue Jan 01 00:00:00 EST 2013
# 1        Tue Jan 01 00:00:00 EST 2013
# 2        Tue Jan 01 00:00:00 EST 2013
# 3        Tue Jan 01 00:00:00 EST 2013
# 4        Tue Jan 01 00:00:00 EST 2013
# 5        Tue Jan 01 00:00:00 EST 2013
# 6        Tue Jan 01 00:00:00 EST 2013
# 7        Tue Jan 01 00:00:00 EST 2013
# 8        Tue Jan 01 00:00:00 EST 2013
# 9        Tue Jan 01 00:00:00 EST 2013
#                      ...
# 41134    Tue Jan 01 00:00:00 EST 2013
# 41135    Tue Jan 01 00:00:00 EST 2013
# 41136    Tue Jan 01 00:00:00 EST 2013
# 41137    Tue Jan 01 00:00:00 EST 2013
# 41138    Tue Jan 01 00:00:00 EST 2013
# 41139    Tue Jan 01 00:00:00 EST 2013
# 41140    Tue Jan 01 00:00:00 EST 2013
# 41141    Tue Jan 01 00:00:00 EST 2013
# 41142    Tue Jan 01 00:00:00 EST 2013
# 41143    Tue Jan 01 00:00:00 EST 2013
# Name: createdOn, Length: 41144, dtype: object

# %%
# add Created on
(autos
 [cols]
 .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
         displ = autos.displ.fillna(0).astype('float16'),
         drive = autos.drive.fillna('Other').astype('category'),
         automatic = autos.trany.str.contains('Auto'), # indicator true/false
         speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'), # extract the digits
         createdOn = pd.to_datetime(autos.createdOn.replace({'EDT':'-04:00', 'EST':'-05:00'},regex=True))
         )
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
 .drop(columns = ['trany'])
 .eng_dscr
 .value_counts(dropna=False)
)
# Out:
# NaN                                   16153
# (FFS)                                  8827
# SIDI                                   5526
# (FFS) CA model                          926
# (FFS)      (MPFI)                       734
# FFV                                     701
# (FFS,TRBO)                              666
# (350 V8) (FFS)                          411
# (GUZZLER)  (FFS)                        366
# SOHC                                    354
#                                       ...
# NG                                        1
# RNG200/300                                1
# GAS 430                                   1
# PHEV; 94 Amp-hour battery                 1
# (GMP4+IC)  (FFS,TRBO) (MPFI)              1
# B234E4 (FFS,TRBO)                         1
# California Emission Control System        1
# FFV; Active Fuel Management               1
# SID                                       1
# AWD (All Wheel Drive)                     1
# ...

# %%
# add ffs( Feedback fuel system), drop eng_dscr

(autos
 [cols]
 .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
         displ = autos.displ.fillna(0).astype('float16'),
         drive = autos.drive.fillna('Other').astype('category'),
         automatic = autos.trany.str.contains('Auto'), # indicator true/false
         speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'), # extract the digits
         createdOn = pd.to_datetime(autos.createdOn.replace({'EDT':'-04:00', 'EST':'-05:00'},regex=True)),
         ffs = autos.eng_dscr.str.contains('FFS') # boolean True/False
         )
 .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
 .drop(columns = ['trany', 'eng_dscr'])
  .memory_usage(deep=True)
  .sum() # was 19,647,323
)
# Out:
# 8677186

# %%
# Take the chain, convert into a glorious function

def tweak_autos(autos):
    cols = ['city08','comb08','highway08','cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year',]
    return(autos
           [cols]
           .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
                   displ = autos.displ.fillna(0).astype('float16'),
                   drive = autos.drive.fillna('Other').astype('category'),
                   automatic = autos.trany.str.contains('Auto'), # indicator true/false
                   speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'), # extract the digits
                   createdOn = pd.to_datetime(autos.createdOn.replace({'EDT':'-04:00', 'EST':'-05:00'},regex=True)),
                   ffs = autos.eng_dscr.str.contains('FFS')
                   )
            .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
            .drop(columns = ['trany', 'eng_dscr'])
        )

tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# ...

# %% [markdown]
# ### Chain
#
# Chaining is also called flow programming. Rather than making intermediate variables, just leverage the fact that most operations return a new object and work on that.
#
# The chain should read like a recipe of ordered steps
#
# (Hint: Leverage .pipe if you can't find a way to pipe)

# %%
# Easy to debug
# - assign to var (df3)
# - comment out
# - pipe to display

def get_var(df, var_name):
    globals()[var_name] = df
    return df

def tweak_autos(autos):
    return (autos
            [cols]
            # create var
            .pipe(get_var, 'df3')
            .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
                   displ = autos.displ.fillna(0).astype('float16'),
                   drive = autos.drive.fillna('Other').astype('category'),
                   automatic = autos.trany.str.contains('Auto'), # indicator true/false
                   speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'), # extract the digits
                   createdOn = pd.to_datetime(autos.createdOn.replace({'EDT':'-04:00', 'EST':'-05:00'},regex=True)),
                   ffs = autos.eng_dscr.str.contains('FFS')
                   )
            # debug pipe
            .pipe(lambda df:display(df) or df)
            .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
            .drop(columns = ['trany', 'eng_dscr'])
            )

tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# ...

# %% [markdown]
# The function get_var takes two parameters:
#
# df: A pandas DataFrame object.
#
# var_name: A string representing the name of a variable.
#
# The purpose of the function is to assign the DataFrame object df to a variable with the name specified by var_name in the global namespace, so that it can be accessed outside the function.
#
# The function achieves this by calling the built-in globals() function to obtain a reference to the global namespace, and then assigning the DataFrame object df to a new variable with the name specified by var_name using square bracket notation ([]).
#
# Finally, the function returns the original DataFrame object df.
#
# Note that this function can be potentially dangerous because it modifies the global namespace, which can lead to unintended consequences and make the code harder to reason about. It is generally recommended to avoid modifying the global namespace unless absolutely necessary.

# %%
# inspect intermediate dataframe
df3
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25        4.0    2.0
# 1           9      11         14       12.0    4.9
# 2          23      27         33        4.0    2.2
# 3          10      11         12        8.0    5.2
# 4          17      19         23        4.0    2.2
# 5          21      22         24        4.0    1.8
# 6          22      25         29        4.0    1.8
# 7          23      24         26        4.0    1.6
# 8          23      26         31        4.0    1.6
# 9          23      25         30        4.0    1.8
# ...       ...     ...        ...        ...    ...
# 41134      18      20         24        4.0    2.1
# 41135      23      26         33        4.0    1.9
# 41136      21      24         30        4.0    1.9
# 41137      24      28         33        4.0    1.9
# 41138      21      25         32        4.0    1.9
# 41139      19      22         26        4.0    2.2
# ...

# %% [markdown]
# ## Don't Mutate
#
# "You are missing the point. inplace rarely actually does something in place, you are thinking you are saving memory but you are not"
#
# In general, no performance benefits
#
# Prohibits chaining
#
# SettingWithCopyWarning fun

# %% [markdown]
# ## Don't Apply (if you can)

# %%
def tweak_autos(autos):
    cols = ['city08','comb08','highway08','cylinders','displ','drive','eng_dscr','fuelCost08','make','model','trany','range','createdOn','year',]
    return(autos
           [cols]
           .assign(cylinders = autos.cylinders.fillna(0).astype('int8'),
                   displ = autos.displ.fillna(0).astype('float16'),
                   drive = autos.drive.fillna('Other').astype('category'),
                   automatic = autos.trany.str.contains('Auto'), # indicator true/false
                   speeds = autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'), # extract the digits
                   createdOn = pd.to_datetime(autos.createdOn.replace({'EDT':'-04:00', 'EST':'-05:00'},regex=True)),
                   ffs = autos.eng_dscr.str.contains('FFS')
                   )
            .astype({'highway08':'int8', 'city08':'int16', 'comb08':'int16', 'fuelCost08':'int16', 'range':'int16', 'year':'int16', 'make':'category'})
            .drop(columns = ['trany', 'eng_dscr'])
        )

tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# ...

# %%
autos2 = tweak_autos(autos)

# This data is US centric miles per gallon. change be Euro Centric litres per 100km
def to_lper100km(val):
    return 235.215 / val

autos2.city08.apply(to_lper100km)
# Out:
# 0        12.379737
# 1        26.135000
# 2        10.226739
# 3        23.521500
# 4        13.836176
# 5        11.200714
# 6        10.691591
# 7        10.226739
# 8        10.226739
# 9        10.226739
#            ...
# 41134    13.067500
# 41135    10.226739
# 41136    11.200714
# 41137     9.800625
# 41138    11.200714
# 41139    12.379737
# 41140    11.760750
# 41141    13.067500
# 41142    13.067500
# 41143    14.700938
# Name: city08, Length: 41144, dtype: float64

# %%
# this gives same results as
235.215 / autos2.city08
# Out:
# 0        12.379737
# 1        26.135000
# 2        10.226739
# 3        23.521500
# 4        13.836176
# 5        11.200714
# 6        10.691591
# 7        10.226739
# 8        10.226739
# 9        10.226739
#            ...
# 41134    13.067500
# 41135    10.226739
# 41136    11.200714
# 41137     9.800625
# 41138    11.200714
# 41139    12.379737
# 41140    11.760750
# 41141    13.067500
# 41142    13.067500
# 41143    14.700938
# Name: city08, Length: 41144, dtype: float64

# %%
# time it 
# %%timeit
autos2.city08.apply(to_lper100km)
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %%
# %%timeit
235.215 / autos2.city08
# Out:
# 568 µs ± 52.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# apply is almost 50 times slower when it comes to numeric data

# %%
def is_american(val):
    return val in {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}

# %%
# %%timeit
autos2.make.apply(is_american)
# Out:
# 3.13 ms ± 66.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
autos2.make.isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'})
# Out:
# 2.06 ms ± 664 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# string timings
# %%timeit
autos2.make.astype(str).isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'})
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %%
# string timings
# %%timeit
autos2.make.astype(str).apply(is_american)
# Out:
# UsageError: Line magic function `%%timeit` not found.

# %% [markdown]
# operations on Categorical is way faster than strings

# %%
def country(val):
    if val in {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}:
        return 'US'
    return 'Other'

# %%
# %%timeit
# Might be ok for strings, since they are not vectorized
(autos2
.assign(country = autos2.make.apply(country))
)
# Out:
# 8.25 ms ± 184 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
values = {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}
(autos2
.assign(country = 'US')
.assign(country = lambda df_:df_.country.where(df_.make.isin(values), 'Other'))
)
# Out:
# 19.9 ms ± 4.13 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit

(autos2
.assign(country=np.select([autos2.make.isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'})],['US'], 'Other'))
)
# Out:
# 17.8 ms ± 3.84 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit

(autos2
.assign(country=np.where(autos2.make.isin({'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}),'US', 'Other'))
)
# Out:
# 13.7 ms ± 1.83 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Take away:
#
# If you are doing numeric processing, avoid apply.
#
# If you are using strings, you are sure of going the slow route anyway. Some operations might be faster using isin

# %% [markdown]
# ## Master Aggregation

# %% [markdown]
# Let us compare mileage by country by year...

# %%
(autos2
 .groupby('year')
 .mean()
)
# Out:
#          city08     comb08  highway08  cylinders     displ   fuelCost08  \
# year
# 1984  17.982688  19.881874  23.075356   5.385438  3.164062  2313.543788
# 1985  17.878307  19.808348  23.042328   5.375661  3.164062  2334.509112
# 1986  17.665289  19.550413  22.699174   5.425620  3.183594  2354.049587
# 1987  17.310345  19.228549  22.445068   5.412189  3.173828  2403.648757
# 1988  17.333628  19.328319  22.702655   5.461947  3.195312  2387.035398
# 1989  17.143972  19.125759  22.465742   5.488291  3.208984  2433.434519
# 1990  17.033395  19.000928  22.337662   5.496289  3.216797  2436.178108
# 1991  16.848940  18.825972  22.253534   5.598940  3.267578  2490.856890
# 1992  16.805531  18.862623  22.439786   5.623550  3.275391  2494.736842
# 1993  16.998170  19.104300  22.780421   5.602928  3.248047  2454.620311
# 1994  16.918534  19.012220  22.725051   5.704684  3.333984  2461.507128
# 1995  16.569804  18.797311  22.671148   5.892451  3.472656  2497.828335
# ...

# %%
# watch order of column filtering/aggregation
(autos2
 .groupby('year')
 [['comb08','speeds']]
 .mean()
)
# Out:
#          comb08    speeds
# year
# 1984  19.881874  3.928208
# 1985  19.808348  3.924750
# 1986  19.550413  3.984298
# 1987  19.228549  4.037690
# 1988  19.328319  4.129204
# 1989  19.125759  4.166522
# 1990  19.000928  4.238404
# 1991  18.825972  4.301237
# 1992  18.862623  4.318466
# 1993  19.104300  4.339433
# 1994  19.012220  4.332994
# 1995  18.797311  4.356774
# 1996  19.584735  4.364812
# 1997  19.429134  4.402887
# 1998  19.518473  4.419951
# 1999  19.611502  4.421362
# 2000  19.526190  4.508333
# 2001  19.479693  4.660812
# 2002  19.168205  4.757949
# 2003  19.000958  4.911877
# 2004  19.067736  4.976827
# 2005  19.193825  5.192110
# 2006  18.959239  5.315217
# 2007  18.978686  5.610124
# 2008  19.276327  5.773378
# 2009  19.735642  6.043074
# 2010  20.588819  6.271416
# 2011  21.011504  6.560177
# 2012  21.819444  6.706597
# 2013  23.125000  6.896959
# 2014  23.531429  6.985306
# 2015  24.038971  7.035853
# 2016  25.150555  7.080032
# 2017  25.249033  7.225058
# ...

# %% [markdown]
# To show order matters

# %%
# %%timeit

(autos2
 .groupby('year')
 [['comb08','speeds']]
 .mean()
)
# Out:
# 7.29 ms ± 199 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit

(autos2
 .groupby('year')
 .mean()
 [['comb08','speeds']] 
)
# Out:
# 21 ms ± 528 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set_context('talk')

# %%
plt.plot(range(10))

# %%
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 # .median()
 # .std()
 # .var()
 .quantile(.1)
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
autos2
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# ...

# %%
def country(val):
    if val in {'Chevrolet', 'Ford', 'Dodge', 'GMC', 'Tesla'}:
        return 'US'
    return 'Other'

# add country
(autos2
 .assign(country=autos.make.apply(country))
 .groupby(['year','country'])
 .mean()
)
# Out:
#                  city08     comb08  highway08  cylinders     displ  \
# year country
# 1984 Other    19.384615  21.417330  24.847038   4.908046  2.691406
#      US       16.079232  17.797119  20.669868   6.033613  3.808594
# 1985 Other    19.284768  21.373068  24.816777   4.871965  2.636719
#      US       16.275472  18.025157  21.020126   5.949686  3.765625
# 1986 Other    19.167183  21.213622  24.650155   4.804954  2.537109
#      US       15.945035  17.645390  20.464539   6.136525  3.925781
# 1987 Other    18.633381  20.710414  24.186876   4.825963  2.583984
#      US       15.611722  17.326007  20.208791   6.164835  3.931641
# 1988 Other    18.668224  20.814642  24.437695   4.819315  2.531250
#      US       15.577869  17.372951  20.420082   6.307377  4.066406
# ...                 ...        ...        ...        ...       ...
# 2016 Other    21.903749  24.439716  28.866261   5.493414  2.992188
#      US       25.061818  27.701818  32.265455   5.356364  3.277344
# ...

# %%
# applying multiple aggregates
def second_to_last(ser):
    return ser.iloc[-2]

(autos2
 .assign(country = autos2.make.apply(country))
 .groupby(['year','country'])
 .agg(['min', 'max', second_to_last])
)
# Out:
#              city08                     comb08                     highway08  \
#                 min  max second_to_last    min  max second_to_last       min
# year country
# 1984 Other        7   38             14      8   41             14         9
#      US           8   35             15      9   39             17        10
# 1985 Other        7   40             19      8   43             20         9
#      US           8   39             14     10   42             15        10
# 1986 Other        6   42             10      7   46             11         9
#      US           9   44             16     10   48             17        11
# 1987 Other        6   42             12      7   46             12         9
#      US           8   44             12      9   47             13        10
# 1988 Other        6   41             12      7   44             12        10
#      US           8   44             14      9   47             14        10
# ...

# %%
# back to simpler examples, adding plots
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year','country'])
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year,country'>

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year','country'])
 .mean()
)
# Out:
#                  city08     comb08  highway08  cylinders     displ  \
# year country
# 1984 Other    19.384615  21.417330  24.847038   4.908046  2.691406
#      US       16.079232  17.797119  20.669868   6.033613  3.808594
# 1985 Other    19.284768  21.373068  24.816777   4.871965  2.636719
#      US       16.275472  18.025157  21.020126   5.949686  3.765625
# 1986 Other    19.167183  21.213622  24.650155   4.804954  2.537109
#      US       15.945035  17.645390  20.464539   6.136525  3.925781
# 1987 Other    18.633381  20.710414  24.186876   4.825963  2.583984
#      US       15.611722  17.326007  20.208791   6.164835  3.931641
# 1988 Other    18.668224  20.814642  24.437695   4.819315  2.531250
#      US       15.577869  17.372951  20.420082   6.307377  4.066406
# ...                 ...        ...        ...        ...       ...
# 2016 Other    21.903749  24.439716  28.866261   5.493414  2.992188
#      US       25.061818  27.701818  32.265455   5.356364  3.277344
# ...

# %% [markdown]
# unstack( ) Take the innermost index which is country and rotate it. Stick it into the columns. We make hierchical columns.

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year','country'])
 .mean()
 .unstack()
)
# Out:
#             city08                comb08             highway08             \
# country      Other         US      Other         US      Other         US
# year
# 1984     19.384615  16.079232  21.417330  17.797119  24.847038  20.669868
# 1985     19.284768  16.275472  21.373068  18.025157  24.816777  21.020126
# 1986     19.167183  15.945035  21.213622  17.645390  24.650155  20.464539
# 1987     18.633381  15.611722  20.710414  17.326007  24.186876  20.208791
# 1988     18.668224  15.577869  20.814642  17.372951  24.437695  20.420082
# 1989     18.533040  15.139831  20.662261  16.908898  24.252570  19.887712
# 1990     18.510109  14.850575  20.640747  16.577011  24.267496  19.485057
# 1991     18.087943  14.803279  20.174468  16.599532  23.809929  19.683841
# 1992     17.915374  14.895631  20.098731  16.735437  23.820874  20.063107
# 1993     18.084866  15.007772  20.309760  16.896373  24.172560  20.230570
# 1994     18.046474  14.952514  20.264423  16.829609  24.173077  20.201117
# ...

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year','country'])
 .mean()
 .unstack()
 .city08 # pull out city08 column
 .plot()
 .legend(bbox_to_anchor=(1,1))
)

# %%
# smoothe it out abit w/ rolling
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year','country'])
 .mean()
 .unstack()
 .rolling(2) # smooth out the plot
 .city08 # pull out city08 column
 .mean()
 .plot()
 .legend(bbox_to_anchor=(1,1))
)

# %%
# filter after grouping
def vals_gt(df_, num): # take a dataframe and number
    return df_[df_.gt(num)].dropna() # return the dataframe where the dataframe.gt is greater than number. Drop NAs

(autos2
 .assign(country = autos2.make.apply(country))
 .groupby(['year', 'country'])
 .count()
 .pipe(vals_gt, 700)
)
# Out:
#               city08  comb08  highway08  cylinders   displ   drive  \
# year country
# 1984 Other    1131.0  1131.0     1131.0     1131.0  1131.0  1131.0
# 1985 Other     906.0   906.0      906.0      906.0   906.0   906.0
# 1991 Other     705.0   705.0      705.0      705.0   705.0   705.0
# 1992 Other     709.0   709.0      709.0      709.0   709.0   709.0
# 1993 Other     707.0   707.0      707.0      707.0   707.0   707.0
# 2017 Other    1017.0  1017.0     1017.0     1017.0  1017.0  1017.0
# 2018 Other    1063.0  1063.0     1063.0     1063.0  1063.0  1063.0
# 2019 Other    1033.0  1033.0     1033.0     1033.0  1033.0  1033.0
#
#               fuelCost08    make   model   range  createdOn  automatic  \
# year country
# 1984 Other        1131.0  1131.0  1131.0  1131.0     1131.0     1131.0
# 1985 Other         906.0   906.0   906.0   906.0      906.0      906.0
# 1991 Other         705.0   705.0   705.0   705.0      705.0      705.0
# ...

# %% [markdown]
# ## Summary
#
# Correct types saves space and enable convinient math, string and date functionality
#
# Chaining operations will
#
# 1. Make code readable
#
# 2. Remove bugs
#
# 3. Easier to debug
#
# Dont mutate, there is no point. Embrace chaining
#
# .apply is slow for math operations
#
# Aggregations are powerful. Play with them until it makes sense
