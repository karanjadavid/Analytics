# %% [markdown]
# # Quantitative comparisons and statistical visualizations

# %% [markdown]
# ## 1.1 Quantitative comparisons: Bar charts
# Bar charts visualize data that is organized according to categories as a series of bars, where the height of each bar represents the values of the data in this category.

# %%
# load libraries
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load the dataframe
medals = pd.read_csv('medals_by_country_2016.csv', index_col=0)
medals
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30
# France             21    20      55
# Australia          25    23      34
# Italy              24     8      38
# Canada             61     4       4
# Japan              34    17      13

# %% [markdown]
# #### Show the gold medals

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label = 'Gold')
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of medals')
ax.set_title('Gold medal standings')
ax.legend()
plt.show()
# Out:
# C:\Users\Dave\AppData\Local\Temp/ipykernel_10804/1139733872.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation = 90)

# %% [markdown]
# ## Stacked bar charts
# A stacked bar chart contains bars, where the height of each bar represents values. In addition, stacked on top of the first variable may be another variable. The additional height of this bar represents the value of this variable. And you can add more bars on top of that.

# %% [markdown]
# #### show the gold and silver medals

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label = 'Gold')
ax.bar(medals.index, medals['Silver'], bottom = medals['Gold'], label = 'Silver')
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of medals')
ax.set_title('Gold and Silver medal standings')
ax.legend()
ax.plot()
# Out:
# C:\Users\Dave\AppData\Local\Temp/ipykernel_10804/2754368236.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation = 90)
# []

# %% [markdown]
# #### show the gold, silver and bronze medals

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label = 'Gold')
ax.bar(medals.index, medals['Silver'], bottom = medals['Gold'], label = 'Silver')
ax.bar(medals.index, medals['Bronze'], bottom = medals['Gold'] + medals['Silver'], label = 'Bronze')
ax.set_xticklabels(medals.index, rotation = 90)
ax.set_ylabel('Number of medals')
ax.set_title('Gold, Silver and Bronze medal standings')
ax.legend()
ax.plot()
# Out:
# C:\Users\Dave\AppData\Local\Temp/ipykernel_10804/221291906.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation = 90)
# []

# %% [markdown]
# ## 1.2 Quantitative comparisons: histograms
# Histograms show the entire distribution of values within a variable.

# %%
# import the dataframe
olympics = pd.read_csv('summer2016.csv')
olympics
# Out:
#       Unnamed: 0      ID                             Name Sex   Age  Height  \
# 0            158      62                Giovanni Abagnale   M  21.0   198.0
# 1            161      65                Patimat Abakarova   F  21.0   165.0
# 2            175      73                        Luc Abalo   M  31.0   182.0
# 3            450     250             Saeid Morad Abdevali   M  26.0   170.0
# 4            794     455      Denis Mikhaylovich Ablyazin   M  24.0   161.0
# ...          ...     ...                              ...  ..   ...     ...
# 2009      269511  134857                         Zhu Ting   F  21.0   198.0
# 2010      270111  135132                    Bojana ivkovi   F  28.0   186.0
# 2011      270281  135205  Shakhobiddin Shokirovich Zoirov   M  23.0   169.0
# 2012      270370  135245                     Milenko Zori   M  27.0   179.0
# 2013      271019  135525                   Martin Zwicker   M  29.0   175.0
#
# ...

# %%
# view the data frame's information
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014 entries, 0 to 2013
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2014 non-null   int64
#  1   ID          2014 non-null   int64
#  2   Name        2014 non-null   object
#  3   Sex         2014 non-null   object
#  4   Age         2014 non-null   float64
#  5   Height      2014 non-null   float64
#  6   Weight      2014 non-null   float64
#  7   Team        2014 non-null   object
#  8   NOC         2014 non-null   object
#  9   Games       2014 non-null   object
#  10  Year        2014 non-null   int64
#  11  Season      2014 non-null   object
#  12  City        2014 non-null   object
#  13  Sport       2014 non-null   object
#  14  Event       2014 non-null   object
#  15  Medal       2014 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 251.9+ KB

# %%
# filter the data frame to select mens' rowing team
mens_rowing = olympics[(olympics['Sex'] == 'M') & (olympics['Sport'] == 'Rowing')]
mens_rowing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 1937
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  84 non-null     int64
#  1   ID          84 non-null     int64
#  2   Name        84 non-null     object
#  3   Sex         84 non-null     object
#  4   Age         84 non-null     float64
#  5   Height      84 non-null     float64
#  6   Weight      84 non-null     float64
#  7   Team        84 non-null     object
#  8   NOC         84 non-null     object
#  9   Games       84 non-null     object
#  10  Year        84 non-null     int64
#  11  Season      84 non-null     object
#  12  City        84 non-null     object
#  13  Sport       84 non-null     object
#  14  Event       84 non-null     object
#  15  Medal       84 non-null     object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 11.2+ KB

# %%
# filter the data frame to select mens' gymnastic team
mens_gymnastics = olympics[(olympics['Sex'] == 'M') & (olympics['Sport'] == 'Gymnastics')]

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing['Weight'], label = 'Rowing')
# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics['Weight'], label = 'Gymnastics')
ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")
ax.legend()
plt.show()

# %% [markdown]
# #### Customizing histograms: setting number of bins
#
# By default, we get 10 bins.

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing['Weight'], label = 'Rowing', bins = 5)
# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics['Weight'], label = 'Gymnastics', bins = 5)
ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")
ax.legend()
plt.show()

# %% [markdown]
# #### customizing histograms: transparency
# change the type of histogram that is used. Instead of the bar type that is used as default, specify histtype of step which displays the histogram as thin lines instead of solid.

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing['Weight'], label = 'Rowing', histtype='step', bins = 5)
# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics['Weight'], label = 'Gymnastics',histtype='step', bins = 5)
ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")
ax.legend()
plt.show()

# %% [markdown]
# ## 1.3 Statistical plotting
# Statistical plotting is a set of methods for using visualizations to make comparisons. Statistical plotting techniques add quantitative information for comparisons into the visualization.
#
# 1. Error bars - These are additional markers on a plot that tell us something about the distribution of the data. Error bars summarize the distribution of the data in one number such as the standard deviation of the values.

# %% [markdown]
# #### Adding error bars to bar charts
# Add the error bar as an argument to a bar chart. Each call to the ax.bar( ) method takes an x argument  y argument and yerr. Add error bars that quantify not only the difference in the means of the height of medalists in the 2016 Olympic Games, but also the standard deviation of each of these groups, as a way to assess whether the difference is substantial relative to the variability within each group.

# %%
fig, ax = plt.subplots()
ax.bar('Rowing', mens_rowing['Height'].mean(), yerr=mens_rowing['Height'].std())
ax.bar('Gymnastics', mens_gymnastics['Height'].mean(), yerr=mens_gymnastics['Height'].std())
ax.set_ylabel('Height (cm) ')
plt.show()

# %% [markdown]
# #### Adding error bars to line plots
#
# fig, ax = plt.subplots()
#
# ax.errorbar(x,y,yerr)
#
# ax.errorbar(x,y,yerr)
#
# ax.set_ylabel('name')
#
# plt.show()

# %%
# load the dataframes
austin_weather = pd.read_csv('austin_weather.csv', index_col='DATE')
seattle_weather = pd.read_csv('seattle_weather.csv',index_col= 'DATE')

# %%
# TRANSFORM THE SEATTLE DATAFRAME

# slice the first 12 rows
seattle_weather = pd.DataFrame(seattle_weather.iloc[:12,:])

# add MONTH column
month_add = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
seattle_weather['MONTH'] = month_add

# TRANSFORM THE AUSTIN DATAFRAME

# add MONTH column
month_add = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
austin_weather['MONTH'] = month_add

# %% [markdown]
# plot the mean temperature across months and add the standard deviation at each point as y errorbars.

# %%
fig, ax = plt.subplots()
ax.errorbar(seattle_weather['MONTH'], seattle_weather['MLY-TAVG-NORMAL'], yerr = seattle_weather['MLY-TAVG-STDDEV'])
ax.errorbar(austin_weather['MONTH'], austin_weather['MLY-TAVG-NORMAL'], yerr= austin_weather['MLY-TAVG-STDDEV'])
ax.set_ylabel('Temperature (Fahrenheit)')
plt.show()

# %% [markdown]
# #### Boxplots
# The boxplot is implemented as a method of the Axes object and we can call it with a sequence of sequences. We create a list of the input data, then add the labels separately.
#
# 1. The red line indicates the median.
# 2. The edges of the box portion at the centre indicate the inter-quartile range of the data, between the 25th and 75th percentile.
# 3.  The whiskers at the ends of the thin bars indicate 1.5 times the size of the interquartile range beyond the 75th and 25th percentile. This encompasses 99% of the distribution if the data is Gaussian or normal.
# 4. Points that appear beyond the whiskers are outliers. They have values larger or smaller than what we'd expect.

# %%
fig, ax = plt.subplots()
ax.boxplot([mens_rowing['Height'], mens_gymnastics['Height']])
ax.set_xticklabels(['Rowing', 'gymnastics'])
ax.set_ylabel('Height (cm)')
plt.show()

# %% [markdown]
# ## 1.4 Quantitative comparisons. Scatter plots
# Scatter are a bi-variate visualization technique. They plot each record in the data as a point. The location of each point is determined by the value of two variables: the first variable determines the distance along the x-axis and the second variable determines the height along the y-axis.

# %%
# load the dataframe
climate_change = pd.read_csv('climate_change.csv', parse_dates=['date'], index_col='date')
climate_change
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06
# ...            ...            ...
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81
#
# [706 rows x 2 columns]

# %%
fig, ax = plt.subplots()
ax.scatter(climate_change['co2'], climate_change['relative_temp'])
ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (Celsius')
plt.show()

# %% [markdown]
# ### Customizing scatter plots

# %%
eighties = climate_change['1980-01-01':'1989-12-31']
nineties = climate_change['1990-01-01':'1999-12-31']

fig, ax = plt.subplots()
ax.scatter(eighties['co2'], eighties['relative_temp'], color = 'red', label = 'eighties')
ax.scatter(nineties['co2'], nineties['relative_temp'], color = 'blue', label = 'nineties')
ax.legend()
ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (Celsius)')
plt.show()

# %% [markdown]
# #### Encoding a third variable by color
# If we enter the index as input to the c-keyword argument, this variable will get encoded as color. Time of the measurements is encoded in the brightness of the color applied to the points.
# Dark blue points early on and later points in bright yellow.

# %%
fig, ax = plt.subplots()
ax.scatter(climate_change['co2'], climate_change['relative_temp'], c=climate_change.index)
ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (Celsius)')
plt.show()
