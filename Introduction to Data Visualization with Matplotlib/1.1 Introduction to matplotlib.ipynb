# %% [markdown]
# # Introduction to matplotlib

# %% [markdown]
# ## 1.1 Introduction

# %%
# import the libraries
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load the dataframes
austin_weather = pd.read_csv('austin_weather.csv', index_col='DATE')
seattle_weather = pd.read_csv('seattle_weather.csv',index_col= 'DATE')

# %%
# TRANSFORM THE DATAFRAME

# slice the first 12 rows
seattle_weather = pd.DataFrame(seattle_weather.iloc[:12,:])

# add MONTH column
month_add = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
seattle_weather['MONTH'] = month_add

# view the seattle weather dataframe 
seattle_weather
# Out:
#           STATION                 NAME  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# DATE
# 1     USC00456295  PALMER 3 ESE, WA US             13.0              1.0
# 2     USC00456295  PALMER 3 ESE, WA US             23.0              3.0
# 3     USC00456295  PALMER 3 ESE, WA US             50.0             11.0
# 4     USC00456295  PALMER 3 ESE, WA US            108.0             40.0
# 5     USC00456295  PALMER 3 ESE, WA US            255.0            130.0
# 6     USC00456295  PALMER 3 ESE, WA US            384.0            237.0
# 7     USC00456295  PALMER 3 ESE, WA US            553.0            398.0
# 8     USC00456295  PALMER 3 ESE, WA US            573.0            418.0
# 9     USC00456295  PALMER 3 ESE, WA US            417.0            270.0
# 10    USC00456295  PALMER 3 ESE, WA US            189.0             81.0
# 11    USC00456295  PALMER 3 ESE, WA US             43.0              9.0
# 12    USC00456295  PALMER 3 ESE, WA US              6.0          -7777.0
#
# ...

# %%
# TRANSFORM THE DATAFRAME

# add MONTH column
month_add = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
austin_weather['MONTH'] = month_add

# view the seattle weather dataframe 
austin_weather
# Out:
#           STATION                                           NAME  \
# DATE
# 1     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 2     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 3     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 4     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 5     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 6     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 7     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 8     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 9     USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 10    USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 11    USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 12    USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
#
#       MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  \
# DATE
# ...

# %% [markdown]
# The plt.subplots( ) command when called without any inputs creates two different objects
# 1. figure object - a container that holds everything that you see on the page
# 2. axes object - the part of the page that holds the data.

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Call the show function to show the result
plt.show()

# %% [markdown]
# ### 1.1.1 Adding data to the axes object

# %% [markdown]
# Adding data to a figure is done by calling methods of the Axes object.
# Using seattle and austin weather data, create a visualization that will allow you to compare the rainfall in these two cities.

# %%
# create a Figure and an Axes object by calling plt.subplots.
fig, ax = plt.subplots()

# Add data from the seattle_weather DataFrame by calling the Axes plot method.
# Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
ax.plot(seattle_weather['MONTH'], seattle_weather["MLY-PRCP-NORMAL"])

# Add data from the austin_weather DataFrame by calling the Axes plot method.
# Plot MLY-PRCP-NORMAL from austin_weather against the MONTH

ax.plot(austin_weather['MONTH'], austin_weather["MLY-PRCP-NORMAL"])

# show the plot
plt.show()

# %% [markdown]
# ## 1.2 Customizing plots

# %% [markdown]
# #### 1. Adding markers
#  use keyword argument marker. used in line plots to show that lines are just connectors to the marker points.
#
# marker = 'x' - letter x
#
# marker = 'v' - upside down v shape
#
# marker = 's' - square
#
# marker = 'o'  circle
#
# marker = 'd'- diamond
#
# marker = '*' - star
#
# marker = 'h' - hexagon
#
#
# #### 2. Setting the linestyle
#
# linestyle = '-' - normal line style
#
# linestyle = '--' - dashed line
#
# linestyle = ':' - dotted line
#
# linestyle = '' - no line
#
# linestyle = 'None' - no line
#
# #### 3. Choosing the color
#
# color = 'r'
#
# color = 'b'
#
# #### 4. Customizing axes labels
#
# ax.set_xlabel(' ')
#
# ax.set_ylabel(' ')
#
# #### 5. Adding a title
#
# ax.set_title(' ')

# %%
# create a Figure and an Axes object by calling plt.subplots.
fig, ax = plt.subplots()

# Plot Seattle data, setting data appearance
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"],
        color='b', marker='o', linestyle='--')

# Plot Austin data, setting data appearance
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
        color='r', marker='v', linestyle='--')

# Customize the x-axis label
ax.set_xlabel("Time (months)")

# Customize the y-axis label
ax.set_ylabel("Precipitation (inches)")

# Add the title
ax.set_title("Weather patterns in Austin and Seattle")

# Call show to display the resulting plot
plt.show()

# %% [markdown]
# ## 1.3 Small multiples
# Too much data becomes messy.
# In matplotlib, small multiples are called subplots( )
#
# Small multiples are typically arranged on the page as a grid with rows and columns.
#
# Default
#
# fig, ax = plt.subplots()
# This blank means it is only one plot.
#
# fig, ax = plt.subplots(3,2)
# This figure object has 3 rows of subplots and two columns.

# %%
# This figure objecy has 3 rows of subplots and two columns.
fig, ax = plt.subplots(3,2)

# %% [markdown]
# #### 1.3.1 Adding data subplots.
# fig, ax = plt.subplots(3, 2)
#
# The variable ax is no longer only one Axes object. It is an array of Axes objects with a shape of 3 by 2
#
# To add data, we index into the ax object and call the plot method on an element of the array.
#
# There is a special case for situations where you have only one row or one column of plots. In this case, the resulting array will be one dimensional and you'll only have to provide one index to access the elements of this array.
#
# To make sure all subjects have the same range of y-axis values, initialize the figure and its subplots with the key argument sharey=True.
#
# fig, ax = plt.subplots(2,1, sharey=True)
#
# This means that both subplots will have the same range of y-axis values, based on the data from both datasets.

# %% [markdown]
# #### Creating small multiples with plt.subplots
# Create a Figure and an array of subplots with 2 rows and 2 columns. Addressing the top left Axes as index 0, 0, plot the Seattle precipitation.
# In the top right (index 0,1), plot Seattle temperatures. In the bottom left (1, 0) and bottom right (1, 1) plot Austin precipitations and temperatures.

# %%
# Create a Figure and an array of subplots with 2 rows and 2 columns
fig, ax = plt.subplots(2, 2)

# Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
ax[0, 0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])

# In the top right (index 0,1), plot month and Seattle temperatures
ax[0, 1].plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])

# In the bottom left (1, 0) plot month and Austin precipitations
ax[1, 0].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])

# In the bottom right (1, 1) plot month and Austin temperatures
ax[1, 1].plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %% [markdown]
# #### Small multiples with shared y axis.
# When creating small multiples, it is often preferable to make sure that the different plots are displayed with the same scale used on the y-axis. This can be configured by setting the sharey key-word to True.

# %%
# Create a figure and an array of axes: 2 rows, 1 column with shared y axis
fig, ax = plt.subplots(2, 1, sharey=True)

# Plot Seattle precipitation in the top axes
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], color='b', linestyle='--')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"], color='b', linestyle='--')

# Plot Austin precipitation in the bottom axes
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"], color='r', linestyle='--')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"], color='r', linestyle='--')

plt.show()
